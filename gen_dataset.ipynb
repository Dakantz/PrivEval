# %% [markdown]
# # Code for how the synthetic data was generated and metric results were computed

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
from synthesis.synthesizers.privbayes import PrivBayes
import tqdm

# %%
#Real dataset generation definition

def generate_real_data(num_samples):
    name_gen = Faker()
    heights = np.around(list(np.random.normal(loc=170, scale=10, size=num_samples)), 2)
    classic_icecreams = [
        "Vanilla", "Chocolate", "Strawberry", "Mint Chocolate Chip",
        "Cookies and Cream", "Rocky Road", "Butter Pecan", "Neapolitan",
        "Pistachio", "French Vanilla"
    ]
    fav_icecream = list(random.choices(classic_icecreams, k=num_samples))

    # Generate random first and last names
    name_df = pd.DataFrame({
        'First Name': [name_gen.first_name() for _ in range(num_samples)],
        'Last Name': [name_gen.last_name() for _ in range(num_samples)]
    })
    height_df = pd.DataFrame({'Height': heights})
    icecream_df = pd.DataFrame({'Flavour': fav_icecream})
    basic_df = pd.concat([name_df, height_df, icecream_df], axis=1)
    
    # Set random seed for reproducibility
    random.seed(42)
    np.random.seed(42)

    # Define country list and correlation rules
    countries = ["USA", "Canada", "Germany", "France", "Italy", "China", "Brazil", "Australia", "Japan", "UK", "Sweden", "Norway", "Denmark", "Finland"]

    # Ice cream preferences (default: random choice)
    ice_creams = ["Vanilla", "Chocolate", "Strawberry", "Mint", "Pistachio", "Stracciatella"]

    # Generate data
    data = []
    for i in range(num_samples):
        person = {}

        # Assign country
        person["Country of Origin"] = random.choice(countries)

        # Assign favorite ice cream with correlation (Italy → Stracciatella preference)
        if person["Country of Origin"] == "Italy":
            person["Favorite Icecream"] = np.random.choice(ice_creams, p=[0.1, 0.1, 0.1, 0.1, 0.2, 0.4])
        else:
            person["Favorite Icecream"] = random.choice(ice_creams)

        # Assign liking for liquorice (Nordic countries → Higher probability)
        if person["Country of Origin"] in ["Sweden", "Norway", "Denmark", "Finland"]:
            person["Like Liquorice"] = np.random.choice([1, 0], p=[0.9, 0.1])  # 70% chance for Nordic countries
        else:
            person["Like Liquorice"] = np.random.choice([1, 0], p=[0.2, 0.8])  # 20% for others

        # Assign number of times visited Italy (Random integer, but higher if from Europe)
        if person["Country of Origin"] in ["Germany", "France", "UK", "Sweden", "Norway", "Denmark", "Finland", "Italy"]:
            person["Times Visited Italy"] = np.random.poisson(2)  # Higher average visits
        else:
            person["Times Visited Italy"] = np.random.poisson(0.5)  # Lower average visits

        # First time in London (UK residents more likely to say yes)
        person["First Time London"] = 1 if person["Country of Origin"] == "UK" else np.random.choice([1, 0], p=[0.2, 0.8])

        # Number of steps per day (Normal distribution with realistic values)
        person["Steps per Day"] = max(1000, int(np.random.normal(8000, 3000)))  # Avoids negative steps

        data.append(person)

    # Create DataFrame
    df = pd.DataFrame(data)
    
    full_df = pd.concat([basic_df, df], axis=1)
    
    return full_df

num_samples = 1500



eps = np.geomspace(0.02, 5.0, 100)
eps_list = eps.tolist()

# %%
# Synthesize dataset with PrivBayes
def synthesize_no_bin(real_data, eps):
    # instantiate and fit synthesizer
    pb = PrivBayes(epsilon=eps, verbose=False, n_cpus=-1)
    pb.fit(real_data)

    # Synthesize data
    gen_data = pb.sample()

    # Save to csv file
    result = pd.DataFrame(
        gen_data.values, columns=gen_data.columns, index=range(real_data.shape[0])
    )

    return result


real_data = generate_real_data(num_samples)
for eps in tqdm.tqdm(eps_list):
    synthesize_no_bin(real_data, eps).to_csv(f"demo_syn/syn_no_1_{eps}.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      11     result = pd.DataFrame(
#      12         gen_data.values, columns=gen_data.columns, index=range(real_data.shape[0])
#      13     )
#      15     return result
# ---> 18 real_data = generate_real_data(num_samples)
#      19 for eps in tqdm.tqdm(eps_list):
#      20     synthesize_no_bin(real_data, eps).to_csv(f"demo_syn/syn_no_1_{eps}.csv")
#
# NameError: name 'generate_real_data' is not defined

# %%
#Get metric results
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from get_metric_results import get_metric_results

df = pd.read_csv("sample_data_1.csv")
epsilon = eps_list
for eps in tqdm.tqdm(epsilon):
    syn_df = pd.read_csv(f"demo_syn/syn_no_1_{eps}.csv", index_col=False).drop(columns=['Unnamed: 0'], errors='ignore')
    # print(syn_df.head())

    all_data = pd.concat([df, syn_df], ignore_index=True)

    cat_cols = all_data.select_dtypes(include=['object', 'bool']).columns

    # Initialize a dictionary to hold encoded data
    encoded_data = {}
    for col in cat_cols:
        if all_data[col].dtype == 'bool':
            encoded_data[col] = all_data[col].astype(int)
        else:
            le = LabelEncoder()
            encoded_data[col] = le.fit_transform(all_data[col].astype(str))

    num_cols = all_data.select_dtypes(exclude=['object', 'bool']).columns
    for col in num_cols:
        encoded_data[col] = all_data[col]

    all_labels = pd.DataFrame(encoded_data)
    real_len = len(df)
    real_labels = all_labels[:real_len]
    syn_labels = all_labels[real_len:]

    metric_results = get_metric_results(df, syn_df, real_labels, syn_labels, sensitive_attributes=['Like Liquorice'])
    # print("Metric Results:")
    # print(metric_results)

    metric_results.to_csv(f"metric_results/syn_no_1_{eps}.csv", index=False)


real_data = pd.read_csv("sample_data_1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 from get_metric_results import get_metric_results
#       6 df = pd.read_csv("sample_data_1.csv")
# ----> 7 epsilon = eps_list
#       8 for eps in tqdm.tqdm(epsilon):
#       9     syn_df = pd.read_csv(f"demo_syn/syn_no_1_{eps}.csv", index_col=False).drop(columns=['Unnamed: 0'], errors='ignore')
#
# NameError: name 'eps_list' is not defined

# %% [markdown]
# ## Get Metric Results for Tabsyn
#
# Here is the code used to get the metric results for the SDG mechanism [Tabsyn](https://doi.org/10.48550/arXiv.2310.09656), using their provided dataset, namely, the [Shoppers](https://doi.org/10.24432/C5F88Q) dataset.

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from get_metric_results import get_metric_results

df = pd.read_csv("Data/real.csv", index_col=False)
syn_df = pd.read_csv("Data/tabsyn.csv", index_col=False)

all_data = pd.concat([df, syn_df], ignore_index=True)

cat_cols = all_data.select_dtypes(include=['object', 'bool']).columns

# Initialize a dictionary to hold encoded data
encoded_data = {}
for col in cat_cols:
    if all_data[col].dtype == 'bool':
        encoded_data[col] = all_data[col].astype(int)
    else:
        le = LabelEncoder()
        encoded_data[col] = le.fit_transform(all_data[col].astype(str))

num_cols = all_data.select_dtypes(exclude=['object', 'bool']).columns
for col in num_cols:
    encoded_data[col] = all_data[col]

all_labels = pd.DataFrame(encoded_data)
real_len = len(df)
real_labels = all_labels[:real_len]
syn_labels = all_labels[real_len:]

metric_results = get_metric_results(df, syn_df, real_labels, syn_labels, sensitive_attributes=['Revenue'])
print("Metric Results:")
print(metric_results)

metric_results.to_csv("metric_results/tabsyn_metric_results.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 30
#      27 real_labels = all_labels[:real_len]
#      28 syn_labels = all_labels[real_len:]
# ---> 30 metric_results = get_metric_results(df, syn_df, real_labels, syn_labels, sensitive_attributes=['Revenue'])
#      31 print("Metric Results:")
#      32 print(metric_results)
#
# File ~/cgv/hereditary/PrivEval/get_metric_results.py:25, in get_metric_results(real_data, syn_data, real_labels, syn_labels, sensitive_attributes)
#      22 def get_metric_results(real_data, syn_data, real_labels, syn_labels, sensitive_attributes=None):
#      24     try:
# ---> 25         mir = MIR.calculate_metric(args=None, _real_data=real_data, _synthetic=syn_data)
#      27     except Exception as e:
#      28         print(f"Error in MIR calculation: {e}")
#
# File ~/cgv/hereditary/PrivEval/Metrics/MemInf.py:73, in calculate_metric(args, _real_data, _synthetic, num_eval_iter)
#      70 # Step 4: Train LightGBM classifier
#      71 # f_θ = LightGBM(D_train)
#      72 cls = LGBMClassifier(verbosity=-1, random_state=42, n_jobs=-1)
# ---> 73 cls.fit(D_train, L_train)
#      75 # Step 5: Make predictions
#      76 # ĥ_i = 1 if f_θ(x_j) >= 0.5, else 0
#      77 y_pred = cls.predict(D_test)
#
# File ~/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py:1560, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1557         else:
#    1558             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1560 super().fit(
#    1561     X,
#    1562     _y,
#    1563     sample_weight=sample_weight,
#    1564     init_score=init_score,
#    1565     eval_set=valid_sets,
#    1566     eval_names=eval_names,
#    1567     eval_sample_weight=eval_sample_weight,
#    1568     eval_class_weight=eval_class_weight,
#    1569     eval_init_score=eval_init_score,
#    1570     eval_metric=eval_metric,
#    1571     feature_name=feature_name,
#    1572     categorical_feature=categorical_feature,
#    1573     callbacks=callbacks,
#    1574     init_model=init_model,
#    1575 )
#    1576 return self
#
# File ~/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/lightgbm/sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/lightgbm/engine.py:322, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     310 for cb in callbacks_before_iter:
#     311     cb(
#     312         callback.CallbackEnv(
#     313             model=booster,
#    (...)    319         )
#     320     )
# --> 322 booster.update(fobj=fobj)
#     324 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     325 # check evaluation result.
#
# File ~/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/lightgbm/basic.py:4155, in Booster.update(self, train_set, fobj)
#    4152 if self.__set_objective_to_none:
#    4153     raise LightGBMError("Cannot update due to null objective function.")
#    4154 _safe_call(
# -> 4155     _LIB.LGBM_BoosterUpdateOneIter(
#    4156         self._handle,
#    4157         ctypes.byref(is_finished),
#    4158     )
#    4159 )
#    4160 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4161 return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Get Metric Results for PrivBayes
#
# Here is the code used to get the metric results for the SDG mechanism [PrivBayes](https://doi.org/10.1145/3134428), using the dataset used in TabSyn, namely, the [Shoppers](https://doi.org/10.24432/C5F88Q) dataset.

# %%
#Synthesize the dataset with PrivBayes
from synthesis.synthesizers.privbayes import PrivBayes

def synthesize_no_bin(real_data, eps):    
    # instantiate and fit synthesizer
    pb = PrivBayes(epsilon=eps, verbose=False, n_cpus=-1)
    pb.fit(real_data)

    # Synthesize data
    gen_data  = pb.sample()

    # Save to csv file
    result = pd.DataFrame(gen_data.values, columns=gen_data.columns, index=range(real_data.shape[0]))
    
    return result

df = pd.read_csv('Data/real.csv')
for eps in tqdm.tqdm(eps_list):
    synthesized_data = synthesize_no_bin(df, eps)
    synthesized_data.to_csv(f'Data/privbayes(e={eps}).csv', index=False)
# Out:
#  31%|███       | 31/100 [06:07<14:35, 12.69s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  32%|███▏      | 32/100 [06:18<13:55, 12.29s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  36%|███▌      | 36/100 [07:13<14:38, 13.72s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  45%|████▌     | 45/100 [08:57<10:42, 11.69s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  46%|████▌     | 46/100 [09:09<10:25, 11.58s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  47%|████▋     | 47/100 [09:20<10:06, 11.44s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  48%|████▊     | 48/100 [09:31<09:48, 11.32s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  50%|█████     | 50/100 [09:54<09:26, 11.34s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  51%|█████     | 51/100 [10:05<09:14, 11.32s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  52%|█████▏    | 52/100 [10:16<09:03, 11.32s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  55%|█████▌    | 55/100 [10:50<08:28, 11.30s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  56%|█████▌    | 56/100 [11:01<08:16, 11.29s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  58%|█████▊    | 58/100 [11:24<07:50, 11.20s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  61%|██████    | 61/100 [11:57<07:18, 11.25s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  62%|██████▏   | 62/100 [12:09<07:11, 11.35s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  64%|██████▍   | 64/100 [12:32<06:50, 11.39s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  65%|██████▌   | 65/100 [12:43<06:36, 11.34s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  66%|██████▌   | 66/100 [12:55<06:27, 11.39s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  67%|██████▋   | 67/100 [13:06<06:16, 11.40s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  68%|██████▊   | 68/100 [13:17<06:04, 11.38s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  69%|██████▉   | 69/100 [13:28<05:51, 11.33s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  70%|███████   | 70/100 [13:40<05:39, 11.33s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  71%|███████   | 71/100 [13:51<05:30, 11.38s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  72%|███████▏  | 72/100 [14:03<05:19, 11.40s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  73%|███████▎  | 73/100 [14:14<05:08, 11.42s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  74%|███████▍  | 74/100 [14:26<04:57, 11.44s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  75%|███████▌  | 75/100 [14:37<04:45, 11.43s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  76%|███████▌  | 76/100 [14:49<04:34, 11.44s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  77%|███████▋  | 77/100 [15:01<04:31, 11.80s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  78%|███████▊  | 78/100 [15:14<04:24, 12.01s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  79%|███████▉  | 79/100 [15:25<04:08, 11.83s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  80%|████████  | 80/100 [15:37<03:55, 11.79s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  81%|████████  | 81/100 [15:49<03:44, 11.82s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  82%|████████▏ | 82/100 [16:01<03:35, 11.94s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  83%|████████▎ | 83/100 [16:13<03:22, 11.93s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  85%|████████▌ | 85/100 [16:38<03:05, 12.33s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  86%|████████▌ | 86/100 [16:50<02:50, 12.14s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  87%|████████▋ | 87/100 [17:02<02:37, 12.15s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  88%|████████▊ | 88/100 [17:15<02:29, 12.42s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  89%|████████▉ | 89/100 [17:27<02:16, 12.36s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  90%|█████████ | 90/100 [17:39<02:03, 12.31s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  91%|█████████ | 91/100 [17:52<01:50, 12.31s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  92%|█████████▏| 92/100 [18:04<01:38, 12.28s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  93%|█████████▎| 93/100 [18:16<01:26, 12.31s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  94%|█████████▍| 94/100 [18:28<01:13, 12.22s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  95%|█████████▌| 95/100 [18:40<01:01, 12.22s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  96%|█████████▌| 96/100 [18:53<00:49, 12.29s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  97%|█████████▋| 97/100 [19:05<00:36, 12.28s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  98%|█████████▊| 98/100 [19:17<00:24, 12.29s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
#  99%|█████████▉| 99/100 [19:30<00:12, 12.24s/it]/home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# /home/bkantz/cgv/hereditary/PrivEval/.venv/lib/python3.12/site-packages/thomas/core/factors/cpt.py:65: RuntimeWarning: invalid value encountered in divide
#   self.values = self.values / row_sum
# 100%|██████████| 100/100 [19:42<00:00, 11.82s/it]

# %%
#Get metric results for PrivBayes
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from get_metric_results import get_metric_results

df = pd.read_csv("Data/real.csv", index_col=False)
for eps in tqdm.tqdm(eps_list):
    syn_df = pd.read_csv(f"Data/privbayes(e={eps}).csv", index_col=False)

    all_data = pd.concat([df, syn_df], ignore_index=True)

    cat_cols = all_data.select_dtypes(include=['object', 'bool']).columns

    # Initialize a dictionary to hold encoded data
    encoded_data = {}
    for col in cat_cols:
        if all_data[col].dtype == 'bool':
            encoded_data[col] = all_data[col].astype(int)
        else:
            le = LabelEncoder()
            encoded_data[col] = le.fit_transform(all_data[col].astype(str))

    num_cols = all_data.select_dtypes(exclude=['object', 'bool']).columns
    for col in num_cols:
        encoded_data[col] = all_data[col]

    all_labels = pd.DataFrame(encoded_data)
    real_len = len(df)
    real_labels = all_labels[:real_len]
    syn_labels = all_labels[real_len:]

    metric_results = get_metric_results(df, syn_df, real_labels, syn_labels, sensitive_attributes=['Revenue'])
    print("Metric Results:")
    print(metric_results)

    metric_results.to_csv(f"metric_results/privbayes(e={eps})_metric_results.csv", index=False)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# MIR evaluation iteration 1/5
# MIR evaluation iteration 2/5
# MIR evaluation iteration 3/5
# MIR evaluation iteration 4/5
# MIR evaluation iteration 5/5
# AIR f1_score: 0.9155142926948449
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
#   1%|          | 1/100 [00:58<1:37:19, 58.99s/it]
# Metric Results:
#                                     Metric  Result
# 0                 Attribute Inference Risk    0.92
# 1                           GeneralizedCAP    0.84
# 2                                  ZeroCAP    0.00
# 3        Median Distance to Closest Record    0.04
# 4                             Hitting Rate    0.00
# 5                Membership Inference Risk    0.00
# 6   Nearest Neighbour Adversarial Accuracy    0.02
# 7                    Common Row Proportion    0.00
# 8     Nearest Synthetic Neighbour Distance    0.88
# 9                  Close Value Probability    0.91
# 10               Distant Value Probability    1.00
# 11                            Authenticity    0.01
# 12                            DetectionMLP    0.00
# 13                   Identifiability Score    0.01
# 14              Distance to Closest Record    0.67
# 15        Nearest Neighbour Distance Ratio    0.32
# 16                             Hidden Rate    0.00
# MIR evaluation iteration 1/5
# MIR evaluation iteration 2/5
# MIR evaluation iteration 3/5
# MIR evaluation iteration 4/5
# MIR evaluation iteration 5/5
# AIR f1_score: 0.752375063241329
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
#   2%|▏         | 2/100 [01:45<1:24:31, 51.75s/it]
# Metric Results:
#                                     Metric  Result
# 0                 Attribute Inference Risk    0.75
# 1                           GeneralizedCAP    0.55
# 2                                  ZeroCAP    0.00
# 3        Median Distance to Closest Record    0.04
# 4                             Hitting Rate    0.00
# 5                Membership Inference Risk    0.00
# 6   Nearest Neighbour Adversarial Accuracy    0.03
# 7                    Common Row Proportion    0.00
# 8     Nearest Synthetic Neighbour Distance    0.88
# 9                  Close Value Probability    0.94
# 10               Distant Value Probability    1.00
# 11                            Authenticity    0.02
# 12                            DetectionMLP    0.00
# 13                   Identifiability Score    0.02
# 14              Distance to Closest Record    0.65
# 15        Nearest Neighbour Distance Ratio    0.34
# 16                             Hidden Rate    0.00
# MIR evaluation iteration 1/5
# MIR evaluation iteration 2/5
# MIR evaluation iteration 3/5
# MIR evaluation iteration 4/5
# MIR evaluation iteration 5/5
# AIR f1_score: 0.8682882055988986
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
#   3%|▎         | 3/100 [02:37<1:23:27, 51.63s/it]
# Metric Results:
#                                     Metric  Result
# 0                 Attribute Inference Risk    0.87
# 1                           GeneralizedCAP    0.80
# 2                                  ZeroCAP    0.00
# 3        Median Distance to Closest Record    0.05
# 4                             Hitting Rate    0.00
# 5                Membership Inference Risk    0.00
# 6   Nearest Neighbour Adversarial Accuracy    0.03
# 7                    Common Row Proportion    0.00
# 8     Nearest Synthetic Neighbour Distance    0.85
# 9                  Close Value Probability    0.84
# 10               Distant Value Probability    1.00
# 11                            Authenticity    0.02
# 12                            DetectionMLP    0.00
# 13                   Identifiability Score    0.01
# 14              Distance to Closest Record    0.67
# 15        Nearest Neighbour Distance Ratio    0.32
# 16                             Hidden Rate    0.00
# MIR evaluation iteration 1/5
# MIR evaluation iteration 2/5
# MIR evaluation iteration 3/5
# MIR evaluation iteration 4/5
# MIR evaluation iteration 5/5
# AIR f1_score: 0.9062145778916761
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
#   4%|▍         | 4/100 [03:24<1:19:52, 49.92s/it]
# Metric Results:
#                                     Metric  Result
# 0                 Attribute Inference Risk    0.91
# 1                           GeneralizedCAP    0.82
# 2                                  ZeroCAP    0.00
# 3        Median Distance to Closest Record    0.04
# 4                             Hitting Rate    0.00
# 5                Membership Inference Risk    0.00
# 6   Nearest Neighbour Adversarial Accuracy    0.03
# 7                    Common Row Proportion    0.00
# 8     Nearest Synthetic Neighbour Distance    0.88
# 9                  Close Value Probability    0.92
# 10               Distant Value Probability    1.00
# 11                            Authenticity    0.02
# 12                            DetectionMLP    0.00
# 13                   Identifiability Score    0.02
# 14              Distance to Closest Record    0.60
# 15        Nearest Neighbour Distance Ratio    0.33
# 16                             Hidden Rate    0.00
# MIR evaluation iteration 1/5
# MIR evaluation iteration 2/5
# MIR evaluation iteration 3/5
# MIR evaluation iteration 4/5
# MIR evaluation iteration 5/5
# AIR f1_score: 0.8597410604192355
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
#   5%|▌         | 5/100 [04:18<1:21:13, 51.30s/it]
# Metric Results:
#                                     Metric  Result
# 0                 Attribute Inference Risk    0.86
# 1                           GeneralizedCAP    0.71
# 2                                  ZeroCAP    0.00
# 3        Median Distance to Closest Record    0.04
# 4                             Hitting Rate    0.00
# 5                Membership Inference Risk    0.00
# 6   Nearest Neighbour Adversarial Accuracy    0.05
# 7                    Common Row Proportion    0.00
# 8     Nearest Synthetic Neighbour Distance    0.90
# 9                  Close Value Probability    0.96
# 10               Distant Value Probability    1.00
# 11                            Authenticity    0.02
# 12                            DetectionMLP    0.00
# 13                   Identifiability Score    0.02
# 14              Distance to Closest Record    0.70
# 15        Nearest Neighbour Distance Ratio    0.33
# 16                             Hidden Rate    0.00
# MIR evaluation iteration 1/5
# MIR evaluation iteration 2/5
# MIR evaluation iteration 3/5
# MIR evaluation iteration 4/5
# MIR evaluation iteration 5/5
# AIR f1_score: 0.9155142926948449
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[num_cols] = a[num_cols].astype("float")
# /home/bkantz/cgv/hereditary/PrivEval/Metrics/NNAA.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b[num_cols] = b[num_cols].astype("float")
#   6%|▌         | 6/100 [05:01<1:16:05, 48.57s/it]
# Metric Results:
#                                     Metric  Result
# 0                 Attribute Inference Risk    0.92
# 1                           GeneralizedCAP    0.84
# 2                                  ZeroCAP    0.00
# 3        Median Distance to Closest Record    0.05
# 4                             Hitting Rate    0.00
# 5                Membership Inference Risk    0.00
# 6   Nearest Neighbour Adversarial Accuracy    0.03
# 7                    Common Row Proportion    0.00
# 8     Nearest Synthetic Neighbour Distance    0.88
# 9                  Close Value Probability    0.93
# 10               Distant Value Probability    1.00
# 11                            Authenticity    0.02
# 12                            DetectionMLP    0.00
# 13                   Identifiability Score    0.02
# 14              Distance to Closest Record    0.73
# 15        Nearest Neighbour Distance Ratio    0.33
# 16                             Hidden Rate    0.00
# MIR evaluation iteration 1/5
# MIR evaluation iteration 2/5
# MIR evaluation iteration 3/5
# MIR evaluation iteration 4/5
# MIR evaluation iteration 5/5
# AIR f1_score: 0.9045950347959133
